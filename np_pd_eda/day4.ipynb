# %%
import numpy as np
import pandas as pd
# pd.Dataframe(
#     {
#         # "Name": 
#     }
# )
# col names as keys and list as data of col

# %%
df = pd.read_csv("data.csv")
df
# Out:
#       Name Subject Hostel Dept
# 0    Harsh      SS    AH1  CSE
# 1    Shree     DSA    AH1  CSE
# 2  Saurabh     EEN     B3  CSE
# 3  Pranith    DSMA     B3  CSE
# 4   Charvi    DSMA     A1  CSE
# 5    Varun      CP     B3  ECE

# %%
df.columns
# Out:
# Index(['Name', 'Subject', 'Hostel', 'Dept'], dtype='object')

# %%
for col in df.columns:
    print(df[col])
# Out:
# 0      Harsh
# 1      Shree
# 2    Saurabh
# 3    Pranith
# 4     Charvi
# 5      Varun
# Name: Name, dtype: object
# 0      SS
# 1     DSA
# 2     EEN
# 3    DSMA
# 4    DSMA
# 5      CP
# Name: Subject, dtype: object
# 0    AH1
# 1    AH1
# 2     B3
# 3     B3
# 4     A1
# 5     B3
# Name: Hostel, dtype: object
# 0    CSE
# 1    CSE
# 2    CSE
# 3    CSE
# 4    CSE
# 5    ECE
# Name: Dept, dtype: object

# %%
df[df["Name"] == "Pranith"]
# Out:
#       Name Subject Hostel Dept
# 3  Pranith    DSMA     B3  CSE

# %%
df.iloc[3]
# Out:
# Name       Pranith
# Subject       DSMA
# Hostel          B3
# Dept           CSE
# Name: 3, dtype: object

# %%
df.loc[3] # as we have not changed indexes
# Out:
# Name       Pranith
# Subject       DSMA
# Hostel          B3
# Dept           CSE
# Name: 3, dtype: object

# %%
# df.index = ["p1","p2","p3","p4","p5","p6"]

# %%
df
# Out:
#       Name Subject Hostel Dept
# 0    Harsh      SS    AH1  CSE
# 1    Shree     DSA    AH1  CSE
# 2  Saurabh     EEN     B3  CSE
# 3  Pranith    DSMA     B3  CSE
# 4   Charvi    DSMA     A1  CSE
# 5    Varun      CP     B3  ECE

# %%
# df.set_index("Name")

# %%
for item in df.groupby("Hostel"):
    print(item)
# Out:
# ('A1',      Name Subject Hostel Dept
# 4  Charvi    DSMA     A1  CSE)
# ('AH1',     Name Subject Hostel Dept
# 0  Harsh      SS    AH1  CSE
# 1  Shree     DSA    AH1  CSE)
# ('B3',       Name Subject Hostel Dept
# 2  Saurabh     EEN     B3  CSE
# 3  Pranith    DSMA     B3  CSE
# 5    Varun      CP     B3  ECE)

# %%
for item in df.groupby("Dept"):
    print(item[0])
# Out:
# CSE
# ECE

# %%
d = df.groupby("Dept").first() # .last()
d
# Out:
#        Name Subject Hostel
# Dept
# CSE   Harsh      SS    AH1
# ECE   Varun      CP     B3

# %%
d = df.groupby("Dept").count()
d
# Out:
#       Name  Subject  Hostel
# Dept
# CSE      5        5       5
# ECE      1        1       1

# %%
d = df.groupby("Dept").min() # or .max() run and see based on first col here name
d
# Out:
#        Name Subject Hostel
# Dept
# CSE   Shree      SS     B3
# ECE   Varun      CP     B3

# %%
# much_data = np.fromfunction(lambda x,y: ())

# %%
# large_df.head() # top 5
# large_df.tail()
# large_df.info() # info about every col
# large_df.describe() # give result of all aggregate func, for each col
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 large_df.head() # top 5
#       2 large_df.tail()
#
# NameError: name 'large_df' is not defined

# %%
# saving 
# my_df.to_csv, or to_json or to_html 
# to_excel("asf.xlsx", sheet_name = "People")
# pd.read_csv("filename",index_col=0) # that will put indices as values of col 0

# %%
# joins in pandas
# pd.merge(left=df_left, right=df_right, on="pk-fk", how="type of join, inner, left, right, outer")
# you can specify, right_on, and left_on
# merge is horizontal 
# .copy() to new instance/duplicate
# concat is vertical, ignore_index = True will have new auto index
# concat also has join = inner
# axis = 1 in concat is just merge

# %%
import pandas as pd
gdf = pd.read_csv("given_data.csv")

# %%
gdf.head()
# Out:
#     Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0    BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1    BMW    1 Series  2011  premium unleaded (required)      300.0
# 2    BMW    1 Series  2011  premium unleaded (required)      300.0
# 3    BMW    1 Series  2011  premium unleaded (required)      230.0
# 4    BMW    1 Series  2011  premium unleaded (required)      230.0
# 5    BMW    1 Series  2012  premium unleaded (required)      230.0
# 6    BMW    1 Series  2012  premium unleaded (required)      300.0
# 7    BMW    1 Series  2012  premium unleaded (required)      300.0
# 8    BMW    1 Series  2012  premium unleaded (required)      230.0
# 9    BMW    1 Series  2013  premium unleaded (required)      230.0
# 10   BMW    1 Series  2013  premium unleaded (required)      300.0
# 11   BMW    1 Series  2013  premium unleaded (required)      230.0
# 12   BMW    1 Series  2013  premium unleaded (required)      300.0
# ...
