# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# gender       object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df["age"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Name: age, Length: 1338, dtype: bool

# %%
df[df["age"].isnull()] # no null value in age
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []

# %%
df[df["bmi"].isnull()] # no null in bmi
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []

# %%
for item in df.columns:
    print(df[df[item].isnull()])
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []

# %%
df["age"].value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#      age gender    bmi  children smoker     region    charges
# 581   19   male  30.59         0     no  northwest  1639.5631

# %%
df[df.duplicated(keep=False)]
# Out:
#      age gender    bmi  children smoker     region    charges
# 195   19   male  30.59         0     no  northwest  1639.5631
# 581   19   male  30.59         0     no  northwest  1639.5631

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [age, gender, bmi, children, smoker, region, charges]
# Index: []

# %%
df.describe(include="all")
# Out:
#                 age gender          bmi     children smoker     region  \
# count   1337.000000   1337  1337.000000  1337.000000   1337       1337
# unique          NaN      2          NaN          NaN      2          4
# top             NaN   male          NaN          NaN     no  southeast
# freq            NaN    675          NaN          NaN   1063        364
# mean      39.222139    NaN    30.663452     1.095737    NaN        NaN
# std       14.044333    NaN     6.100468     1.205571    NaN        NaN
# min       18.000000    NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000    NaN    26.290000     0.000000    NaN        NaN
# 50%       39.000000    NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000    NaN    34.700000     2.000000    NaN        NaN
# max       64.000000    NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1337.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# gender is a categorical variable
df["gender"].value_counts()
# Out:
# male      675
# female    662
# Name: gender, dtype: int64

# %%
plt.pie(df["gender"].value_counts(),labels=df["gender"].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f052261b790>,
# ...
#  [Text(-0.016800012982034103, 1.0998717014105799, 'male'),
#   Text(0.01680011595945443, -1.0998716998376443, 'female')])

# %%
plt.bar(df["age"].value_counts().index,df["age"].value_counts().values)
# Out:
# <BarContainer object of 47 artists>

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.boxplot(df["bmi"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0522630310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f052037cb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f05225f5b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0520389c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0520389390>],
#  'means': []}

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.pie(df["children"].value_counts(),labels=df["children"].value_counts().index) # categorical variable
# Out:
# ([<matplotlib.patches.Wedge at 0x7f05203c5b50>,
# ...
#  [Text(0.2447730130080499, 1.0724207066739067, '0'),
#   Text(-1.0467198531072106, -0.33819750015518996, '1'),
#   Text(0.0736090716588521, -1.09753437511976, '2'),
#   Text(0.9255059033806083, -0.5945072100552224, '3'),
#   Text(1.0887198297987304, -0.1571277575828781, '4'),
#   Text(1.0990162607692266, -0.046510843518769523, '5')])

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.pie(df["region"].value_counts(),labels=df["region"].value_counts().index) # categorical variable
# Out:
# ([<matplotlib.patches.Wedge at 0x7f052024a650>,
# ...
#  [Text(0.7215890706705311, 0.8302464773119123, 'southeast'),
#   Text(-0.8640286077747883, 0.6807749737958654, 'southwest'),
#   Text(-0.7196362470877354, -0.8319397044723132, 'northwest'),
#   Text(0.7963235543877186, -0.7588601957721266, 'northeast')])

# %%
import seaborn as sns
sns.displot(df["age"], kde=True)

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.pie(df["smoker"].value_counts(),labels=df["smoker"].value_counts().index) # categorical variable
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0520099650>,
# ...
#  [Text(-0.8797849777822367, 0.6602865990376524, 'no'),
#   Text(0.8797849468719889, -0.6602866402233593, 'yes')])

# %%
sns.displot(df["charges"], kde=True)

# %%
plt.boxplot(df["age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f051ffc5cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f051ffc7410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f051feed310>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f051ffd89d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0522886310>],
#  'means': []}

# %%
plt.boxplot(df["bmi"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f051fdf6710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f051fe30190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f051fdef5d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f051fe31610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f051fe32010>],
#  'means': []}

# %%
plt.boxplot(df["charges"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f051fe92110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f051fe93850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f051fe75310>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f051fea4dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f051fea5810>],
#  'means': []}

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.scatter(df["age"],df["children"])

# %%
plt.scatter(df["age"],df["smoker"])

# %%
plt.scatter(df["age"],df["charges"])

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.scatter(df["age"],df["bmi"])

# %%
sns.pairplot(df)

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
plt.scatter(df["smoker"],df["charges"])
